# %%
import pandas as pd
a = pd.read_parquet("~/swcamp4/data/movies_after/meta")
a
# Out:
#      movieCd                               movieNm    salesAmt  salesInten  \
# 0   20203702                            노량: 죽음의 바다  2893509165  -686119312
# 1   20212866                                 서울의 봄  2666429137  -649456909
# 2   20236146  신차원! 짱구는 못말려 더 무비 초능력 대결전 ~날아라 수제김밥~   565417320   -69888800
# 3   20235735                          아쿠아맨과 로스트 킹덤   507984981  -156026099
# 4   20235596                            트롤: 밴드 투게더   273538754   -16945147
# 5   20234673                      뽀로로 극장판 슈퍼스타 대모험   113680587     2278496
# 6   20235290                             도티와 영원의 탑   100024717   -13487835
# 7   20234114                                    괴물    92381680    -3768994
# 8   20236045  바다 탐험대 옥토넛 어보브 앤 비욘드: 버드, 옥토경보를 울려라!    53094530     -707720
# 9   20235980                             말하고 싶은 비밀    38025184    -2349427
# 10  20190324                                3일의 휴가    28109697    -5429437
# ...

# %%
b = pd.read_parquet("/Users/joon/swcamp4/data/movies/merge/dailyboxoffice/dt=20240102")
b
# Out:
#      movieCd                               movieNm   salesAmt  salesInten  \
# 0   20203702                            노량: 죽음의 바다  657033879 -2236475286
# 1   20212866                                 서울의 봄  645476622 -2020952515
# 2   20236146  신차원! 짱구는 못말려 더 무비 초능력 대결전 ~날아라 수제김밥~  178944713  -386472607
# 3   20235735                          아쿠아맨과 로스트 킹덤  142162716  -365822265
# 4   20235596                            트롤: 밴드 투게더   67630105  -205908649
# 5   20234673                      뽀로로 극장판 슈퍼스타 대모험   45552045   -68128542
# 6   20234114                                    괴물   43315128   -49066552
# 7   20235290                             도티와 영원의 탑   32972556   -67052161
# 8   20236045  바다 탐험대 옥토넛 어보브 앤 비욘드: 버드, 옥토경보를 울려라!   26098300   -26996230
# 9   20233299                                  크레센도   15612000   -13591100
# 10  20236080                         류이치 사카모토: 오퍼스   18130115   -13556835
# 11  20190324                                3일의 휴가   13358423   -14751274
# ...

# %%
def fillna_meta(prev_df, cur_df):
    if prev_df is None or prev_df.empty:
        return cur_df

    cols = [
        "movieNm", "rank", "rnum", 
        "salesAmt", "salesInten", "salesChange", "salesAcc",
        "audiCnt", "audiInten", "audiChange", "audiAcc",
        "scrnCnt", "showCnt",
        "multiMovieYn", "repNationCd"
    ]
    
    merged_df = prev_df.merge(cur_df, on="movieCd", how="outer", suffixes=("_A", "_B"))
    for c in cols:
        merged_df[c] = merged_df[f"{c}_A"].combine_first(merged_df[f"{c}_B"])
        merged_df.drop(columns=[f"{c}_A" for  + [f"{c}_B" for c in cols], inplace=True)
    
    return merged_df

# %%
fillna_meta(a, b).columns
# Out:
# Index(['movieCd', 'movieNm_A', 'salesAmt_A', 'salesInten_A', 'salesChange_A',
#        'salesAcc_A', 'audiCnt_A', 'audiInten_A', 'audiChange_A', 'audiAcc_A',
#        'scrnCnt_A', 'showCnt_A', 'repNationCd_A', 'multiMovieYn_A', 'rnum_A',
#        'rank_A', 'dt_A', 'movieNm_B', 'salesAmt_B', 'salesInten_B',
#        'salesChange_B', 'salesAcc_B', 'audiCnt_B', 'audiInten_B',
#        'audiChange_B', 'audiAcc_B', 'scrnCnt_B', 'showCnt_B', 'multiMovieYn_B',
#        'repNationCd_B', 'rnum_B', 'rank_B', 'dt_B'],
#       dtype='object')
