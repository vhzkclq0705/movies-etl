# %%
import pandas as pd
df = pd.read_parquet("~/swcamp4/data/movies_after/meta")
df
# Out:
#     audiCnt    salesAmt  rnum   audiAcc   movieCd rankOldAndNew  audiChange  \
# 0    290717  2893509165     1   3728850  20203702           OLD       -16.9
# 1    262422  2666429137     2  12117201  20212866           OLD       -19.6
# 2     58239   565417320     3    626508  20236146           OLD       -10.4
# 3     49368   507984981     4    772354  20235735           OLD       -22.9
# 4     28988   273538754     5    365927  20235596           OLD        -6.3
# 5     11586   113680587     6    332776  20234673           OLD         1.7
# 6     10704   100024717     7     52400  20235290           OLD       -10.6
# 7      8710    92381680     8    396137  20234114           OLD        -5.7
# 8      6471    53094530     9     45294  20236045           OLD         1.0
# 9      3765    38025184    10     89597  20235980           OLD        -4.2
# 10     3295    28109697    11    517836  20190324           OLD       -16.0
# ...

# %%
a = pd.read_parquet("/Users/joon/swcamp4/data/movies/merge/dailyboxoffice/dt=20240101")
a
# Out:
#     audiCnt    salesAmt  rnum   audiAcc   movieCd rankOldAndNew  audiChange  \
# 0    290717  2893509165     1   3728850  20203702           OLD       -16.9
# 1    262422  2666429137     2  12117201  20212866           OLD       -19.6
# 2     58239   565417320     3    626508  20236146           OLD       -10.4
# 3     49368   507984981     4    772354  20235735           OLD       -22.9
# 4     28988   273538754     5    365927  20235596           OLD        -6.3
# 5     11586   113680587     6    332776  20234673           OLD         1.7
# 6     10704   100024717     7     52400  20235290           OLD       -10.6
# 7      8710    92381680     8    396137  20234114           OLD        -5.7
# 8      6471    53094530     9     45294  20236045           OLD         1.0
# 9      3765    38025184    10     89597  20235980           OLD        -4.2
# 10     3295    28109697    11    517836  20190324           OLD       -16.0
# ...
