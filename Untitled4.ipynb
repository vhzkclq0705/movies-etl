# %%
import pandas as pd
pd.read_parquet("/Users/joon/swcamp4/data/movies_after")

# %%
df
# Out:
#                                  movieNm  audiCnt multiMovieYn repNationCd  \
# 0                             노량: 죽음의 바다    70990            N           K
# 1                                  서울의 봄    67766            N           K
# 2   신차원! 짱구는 못말려 더 무비 초능력 대결전 ~날아라 수제김밥~    19367            N           F
# 3                           아쿠아맨과 로스트 킹덤    14940            N           F
# 4                             트롤: 밴드 투게더     7557            N           F
# 5                       뽀로로 극장판 슈퍼스타 대모험     4826            N           K
# 6                                     괴물     4366            Y           F
# 7                              도티와 영원의 탑     3777            N           K
# 8   바다 탐험대 옥토넛 어보브 앤 비욘드: 버드, 옥토경보를 울려라!     3343            Y           F
# 9                                   크레센도     1920            Y           F
# 10                         류이치 사카모토: 오퍼스     1888            Y           F
# ...
