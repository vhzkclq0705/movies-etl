# %%
import pandas as pd
pd.read_parquet("~/swcamp4/data/movies_after/meta")
# Out:
#      movieCd        dt                               movieNm   audiCnt  rank  \
# 0   19580069  20240105                                     돈      51.0  24.0
# 1   19810057  20240105                               콰이강의 다리     235.0  21.0
# 2   19860125  20240105                                  쿼바디스     292.0  20.0
# 3   20124722  20240105                             피아니스트의 전설     294.0  19.0
# 4   20190324  20240105                                3일의 휴가    3295.0  11.0
# 5   20202247  20240105                               싱글 인 서울     212.0  21.0
# 6   20203702  20240105                            노량: 죽음의 바다  290717.0   1.0
# 7   20212866  20240105                                 서울의 봄  262422.0   2.0
# 8   20227525  20240105                             교토에서 온 편지      29.0  25.0
# 9   20227654  20240105                                    수라     172.0  20.0
# 10  20228555  20240105                            더 퍼스트 슬램덩크    8114.0   5.0
# ...
