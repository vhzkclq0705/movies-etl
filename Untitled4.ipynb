# %%
import pandas as pd
pd.read_parquet("~/swcamp4/data/movies/dailyboxoffice/dt=20240107")
# Out:
#     rnum  rank  rankInten rankOldAndNew   movieCd  \
# 0      1     1          0           OLD  20235834
# 1      2     2          0           OLD  20203702
# 2      3     3          0           OLD  20212866
# 3      4     4          0           OLD  20236146
# 4      5     5          0           OLD  20235735
# 5      6     6          1           OLD  20228555
# 6      7     7         -1           OLD  20234114
# 7      8     8          0           OLD  20235596
# 8      9     9          0           OLD  20234673
# 9     10    10          0           OLD  20236045
# 10     1     1          0           OLD  20235834
# 11     2     2          0           OLD  20203702
# 12     3     3          0           OLD  20212866
# 13     4     4          0           OLD  20236146
# 14     5     5          0           OLD  20235735
# 15     6     6          0           OLD  20228555
# 16     7     7          0           OLD  20235596
# 17     8     8          0           OLD  20234673
# ...
